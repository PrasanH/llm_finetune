# %%
from bs4 import BeautifulSoup
import random

# %%
# Load and parse the TMX file
# The TMX file has contents in html format. To parse it, we will use BeautifulSoup package
# The file has several translational pairs/units(tu)

tmx_file = r"dataset\de-fr_04-11-2015_Website_final_stripped.tmx"
with open(tmx_file, 'r', encoding='utf-8') as f:
    soup = BeautifulSoup(f, 'xml')

# %%
translation_pairs = []
for tu in soup.find_all('tu'):
    source_text = tu.find_all('tuv')[0].seg.get_text()
    target_text = tu.find_all('tuv')[1].seg.get_text()
    translation_pairs.append((source_text, target_text))

# %%
print('Total translational pairs=', len(translation_pairs))
print('sample translational pairs',translation_pairs[0:5])
# Out:
# Total translational pairs= 11852
# sample translational pairs [('Im Mittelpunkt des Gesprächs standen der Nahost-Friedensprozess und die Lage in den palästinensischen Gebieten.', 'Le processus de paix au Proche-Orient et la situation dans les territoires palestiniens ont été au cœur des entretiens.'), ('In ein intensives Gespräch vertieft ©\xa0Photothek/Gottschalk', 'Les deux responsables plongés dans une intense discussion'), ('Daneben ging es in der Unterredung auch um regionale Themen:', 'Leurs échanges ont également porté sur des thèmes régionaux\xa0:'), ('Vertiefter Austausch zum Friedensprozess', 'Un échange approfondi sur le processus de paix'), ('Wirtschaftliche Entwicklung stärken', 'Renforcer le développement économique')]

# %%
random.seed(42)
selected_pairs = random.sample(translation_pairs, 1000) # Select randomly 1000 pairs from the available using random seed

print(selected_pairs)

if len(selected_pairs) == len(set(selected_pairs)):
    print("No duplicates found in the selected samples")
# Out:
# [('Vorschläge zur Erörterung durch die Arbeitsgruppe Politik lägen nun auf dem Tisch.', 'Les propositions sont maintenant sur la table, a-t-il continué, et c’est au groupe de travail politique de les examiner.'), ('Es sei nötig, dass Russland der Entsendung einer OSZE-Beobachtermission zustimme, vor allem in die Ost- und Südukraine.', 'Il est selon lui nécessaire que la Russie approuve l’envoi d’une mission d’observation de l’OSCE, surtout dans l’Est et le Sud de l’Ukraine.'), ('Der 100. Jahrestag des Beginns des Ersten Weltkriegs, der 75. Jahrestag des Beginns des Zweiten Weltkriegs und der 25. Jahrestag des Falls der Berliner Mauer liegen alle im Jahr 2014!', 'Elle marquera en effet non seulement le centenaire du début de la Première guerre mondiale mais aussi les 75\xa0ans du début de la Deuxième Guerre mondiale et le 25e\xa0anniversaire de la chute du mur de Berlin.'), ('Weiterbildung und Praktika', 'Formation continue et stages'), ('Gespräche im EU-Außenrat geprägt von Trauer und Entsetzen nach MH17-Absturz /', 'Tristesse et effroi au conseil «\xa0Affaires étrangères\xa0» après le crash du MH\xa017'), ('Darüber werden wir in diesen Tagen mit Premier Jomaa in Berlin weiter beraten.', 'Nous continuerons également de discuter ces jours-ci à Berlin avec le premier ministre M.\xa0Jomaâ de la façon dont nous pouvons nous y prendre.'), ('Außerdem engagiert sich Deutschland in Somalia mit Maßnahmen der entwicklungsfördernden und strukturbildenden Übergangshilfe und unterstützt somalische Flüchtlinge in den großen Flüchtlingslagern in Kenia und Äthiopien.', 'Par ailleurs, l’Allemagne s’engage en Somalie par le biais de mesures d’aide à la transition fondées sur le soutien au développement et l’établissement de structures. Elle soutient également les réfugiés somaliens dans les grands camp de réfugiés au Kenya et en Éthiopie.'), ('Julikrise 1914 - Schlafwandelnde Diplomaten?', 'La crise de juillet 1914\xa0: des diplomates somnanbules\xa0?'), ('Externer Link, öffnet in neuem FensterDie Studie "A New Climate for Peace" (Englisch)', 'Externer Link, öffnet in neuem FensterDie Studie «\xa0A New Climate for Peace\xa0» (en anglais)'), ('Laut Bundestagsbeschluss können bis zum 30. Juni 2016 unverändert bis zu 300 Soldatinnen und Soldaten vor den Küsten des Libanon im Einsatz sein.', 'Conformément à la décision du Bundestag et comme dans le précédent mandat, jusqu’à 300\xa0militaires pourront être déployés au large des côtes libanaises jusqu’au 30\xa0juin 2016.'), ('Portugal (2)', 'Portugal (2)'), ('Steinmeier bei seiner Rede vor dem UN-Menschenrechtsrat ©\xa0Photothek/Trutschel', 'M.\xa0Steinmeier lors de son allocution devant le Conseil des droits de l’homme ©\xa0Photothek/Trutschel'), ('Darum geht es in den nächsten Stunden, in den nächsten Tagen.', 'C’est tout l’enjeu des prochaines heures et des prochains jours.'), ('Östliche Partnerschaft der EU (auf deutsch)', 'Partenariat oriental de l’UE (en allemand)'), ('Wenn du unseren Newsletter abonnierst, erhältst du einmal im Monat Infos zu aktuellen Angeboten auf PASCH-net.', 'En t’abonnant à notre lettre d’information, tu recevras chaque mois des informations sur les offres actuelles de PASCH-net.'), ('Innerhalb der Zusammenarbeit mit den 28 EU-Mitgliedsstaaten nimmt die deutsch-französische Partnerschaft durch ihre Geschichte, ihre Intensität und ihre besondere institutionelle Ausgestaltung eine herausgehobene Stellung ein.', 'En raison de son histoire, de son intensité et de son organisation institutionnelle particulière, le partenariat franco-allemand occupe une place à part dans la coopération des 28\xa0États membres de l’Union européenne.'), ('Gleichgewicht zwischen Freiheit und Sicherheit', 'Équilibre entre liberté et sécurité'), ('In einen Saal voller Journalisten, Blogger, Twitterer und Social-Media-Experten hätte er gern so etwas wie "Breaking News" mitgebracht - aber leider könne er das an diesem Tag nicht.', 'Le chef de la diplomatie allemande a dit qu’il aurait aimé présenter à ...
# No duplicates found in the selected samples

# %%
import csv

# Save selected translation pairs to a CSV file
csv_file = 'short_dataset\selected_pairs.csv'

with open(csv_file, 'w', encoding='utf-8', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['Source Text', 'Target Text'])  # Optional: Add header
    writer.writerows(selected_pairs)

print(f"Saved {len(selected_pairs)} translation pairs to {csv_file}.")
# Out:
# Saved 1000 translation pairs to short_dataset\selected_pairs.csv.
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\prasa\AppData\Local\Temp\ipykernel_19476\2039425427.py:4: SyntaxWarning: invalid escape sequence '\s'
#   csv_file = 'short_dataset\selected_pairs.csv'

# %%
import json
with open('short_dataset\selected_pairs.json', 'w', encoding='utf-8') as f:
    json.dump(selected_pairs, f, ensure_ascii=False, indent=4)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\prasa\AppData\Local\Temp\ipykernel_19476\528757362.py:2: SyntaxWarning: invalid escape sequence '\s'
#   with open('short_dataset\selected_pairs.json', 'w', encoding='utf-8') as f:
